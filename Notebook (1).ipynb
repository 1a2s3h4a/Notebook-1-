# %% [markdown]
# # "My Jupyter Notebook in Watson Studio"

# %% [markdown]
# <b>Asha Sangwan

# %% [markdown]
# Current- Student
# Desired occuption - Data Scientist

# %% [markdown]
# '_'I am interested in data science because it is an unexploited and insightfull tool which is the backbone of the future.

# %% [markdown]
# # Guess the output

# %%
a = 3
a = a + 1
print("The value of a is" , a)
# Out:
# The value of a is 4

# %% [markdown]
# # Top 5 Richest Person

# %% [markdown]
# 1. Elon Musk
# 2. &Gautam Adani
# 3. Jeff Bezos
# 4. Bernard Arnault
# 5.
